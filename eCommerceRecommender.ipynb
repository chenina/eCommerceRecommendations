# %%
import pandas as pd
fullShoeData = pd.read_csv('MensShoesData.csv')
fullShoeData.head()
# Out:
#                      id asins                brand  \
# 0  AVpfHrJ6ilAPnD_xVXOI   NaN                Josmo
# 1  AVpfHrJ6ilAPnD_xVXOI   NaN                Josmo
# 2  AVpfHsWP1cnluZ0-eVZ7   NaN  SERVUS BY HONEYWELL
# 3  AVpfHsWP1cnluZ0-eVZ7   NaN  SERVUS BY HONEYWELL
# 4  AVpfHsWP1cnluZ0-eVZ7   NaN  SERVUS BY HONEYWELL
#
#                                    categories colors  count  \
# 0  Clothing,Shoes,Men's Shoes,All Men's Shoes    NaN    NaN
# 1  Clothing,Shoes,Men's Shoes,All Men's Shoes    NaN    NaN
# 2  All Men's Shoes,Shoes,Men's Shoes,Clothing    NaN    NaN
# 3  All Men's Shoes,Shoes,Men's Shoes,Clothing    NaN    NaN
# 4  All Men's Shoes,Shoes,Men's Shoes,Clothing    NaN    NaN
#
#               dateAdded           dateUpdated  \
# 0  2016-11-07T00:45:12Z  2016-11-07T00:45:12Z
# 1  2016-11-07T00:45:12Z  2016-11-07T00:45:12Z
# 2  2016-06-14T04:29:57Z  2016-07-09T20:26:48Z
# 3  2016-06-14T04:29:57Z  2016-07-09T20:26:48Z
# 4  2016-06-14T04:29:57Z  2016-07-09T20:26:48Z
#
# ...

# %%
fullShoeData.describe()
# Out:
#        count           ean  flavors  isbn
# count    0.0  9.999000e+03      0.0   0.0
# mean     NaN  8.369699e+11      NaN   NaN
# std      NaN  1.021830e+12      NaN   NaN
# min      NaN  1.014667e+07      NaN   NaN
# 25%      NaN  6.759120e+11      NaN   NaN
# 50%      NaN  8.367770e+11      NaN   NaN
# 75%      NaN  8.871200e+11      NaN   NaN
# max      NaN  9.417000e+12      NaN   NaN

# %%
list(fullShoeData.columns.values)
# Out:
# ['id',
#  'asins',
#  'brand',
#  'categories',
#  'colors',
#  'count',
#  'dateAdded',
#  'dateUpdated',
#  'descriptions',
#  'dimension',
#  'ean',
#  'features',
#  'flavors',
#  'imageURLs',
#  'isbn',
#  'keys',
#  'manufacturer',
#  'manufacturerNumber',
#  'merchants',
#  'name',
#  'prices.amountMin',
#  'prices.amountMax',
#  'prices.availability',
#  'prices.color',
#  'prices.condition',
#  'prices.count',
#  'prices.currency',
#  'prices.dateAdded',
#  'prices.dateSeen',
#  'prices.flavor',
#  'prices.isSale',
#  'prices.merchant',
#  'prices.offer',
#  'prices.returnPolicy',
#  'prices.shipping',
#  'prices.size',
#  'prices.source',
#  'prices.sourceURLs',
#  'prices.warranty',
#  'quantities',
#  'reviews',
#  'sizes',
#  'skus',
#  'sourceURLs',
#  'upc',
#  'vin',
#  'websiteIDs',
#  'weight',
#  'Unnamed: 48']

# %%
shoeData = fullShoeData[['brand','colors','categories','dateUpdated','manufacturer','prices.amountMin','name']]

# %%
shoeData.describe()
# Out:
#         brand colors                                  categories  \
# count   19129  11048                                       19387
# unique   1960   2237                                        1264
# top      Nike  Black  All Men's Shoes,Shoes,Men's Shoes,Clothing
# freq     1710   1512                                        3717
#
#                  dateUpdated manufacturer prices.amountMin  \
# count                  19387         6699            19377
# unique                  7990          675             5701
# top     2016-02-25T20:49:59Z         Puma               65
# freq                     106          476              228
#
#                               name
# count                        19387
# unique                        9670
# top     Harold Suede Tassel Driver
# freq                           106

# %%
# Portwest Shoe Example
shoeData.loc[1004]
# Out:
# brand                                                 Portwest
# colors                                              Multicolor
# categories          All Men's Shoes,Shoes,Men's Shoes,Clothing
# dateUpdated                               2016-11-15T13:26:36Z
# manufacturer                                               NaN
# prices.amountMin                                         40.81
# Name: 1004, dtype: object

# %%
#Nike Shoe Example
shoeData.loc[2004]
# Out:
# brand                                                            Nike
# colors                                   BronzeBambooBlue RibbonBlack
# categories          Athletic,Clothing, Shoes & Accessories,Men's S...
# dateUpdated                                      2016-05-02T02:14:20Z
# manufacturer                                                      NaN
# prices.amountMin                                                119.5
# Name: 2004, dtype: object

# %%
#Second Nike Shoe Example
shoeData.loc[218]
# Out:
# brand                                                     Nike
# colors                                                     NaN
# categories          All Men's Shoes,Shoes,Men's Shoes,Clothing
# dateUpdated                               2016-11-07T00:00:17Z
# manufacturer                                              Nike
# prices.amountMin                                           150
# Name: 218, dtype: object

# %% [markdown]
# # Simple Similarity Score Algorithm

# %%
def getSimilarity(shoeRowNum1,shoeRowNum2):
    shoe1 = shoeData.loc[shoeRowNum1]
    shoe2 = shoeData.loc[shoeRowNum2]
    
    similarityScore = 0
    
    if shoe1['brand'] == shoe2['brand']:
        similarityScore += 1
    if shoe1['colors'] == shoe2['colors']:
        similarityScore += 1
    if shoe1['categories'] == shoe2['categories']:
        similarityScore += 1
    if shoe1['manufacturer'] == shoe2['manufacturer']:
        similarityScore += 1
        
    differenceInPrice = abs(float(shoe1['prices.amountMin']) - float(shoe2['prices.amountMin']))
                  
    if differenceInPrice <= 5:
        similarityScore += 3
    if differenceInPrice <= 25: 
        similarityScore += 2
    if differenceInPrice <= 45: 
        similarityScore += 1
    if differenceInPrice >= 45: 
        similarityScore += 0

    print(similarityScore)

# %% [markdown]
# # Compare a few shoes

# %%
#TWO VERY DIFFERENT SHOES
getSimilarity(1004,2004)
# Out:
# 0

# %%
#TWO MORE SIMILAR SHOES
getSimilarity(218,2004)
# Out:
# 2

# %%
def getSimilaritiesForAll(shoeRowNum):
    numberOfShoes = len(shoeData)
    similarityScores = []
    
    
    for row in range(0,numberOfShoes):
        similarityScores.append(getSimilarity(shoeRowNum,row))
    
    return similarityScores

# %%
getSimilaritiesForAll(5)
# Out:
# 3
# 6
# 5
# 5
# 5
# 8
# 5
# 5
# 3
# 5
# 3
# 0
# 0
# 1
# 2
# 2
# 2
# 1
# 3
# 0
# 1
# 1
# 6
# 6
# 3
# 0
# 1
# 0
# 4
# 2
# 2
# 2
# 3
# 3
# 6
# 0
# 6
# 3
# 3
# 1
# 1
# 3
# 3
# 0
# 1
# 3
# 1
# 7
# 7
# 4
# 4
# 0
# 1
# 1
# 1
# 3
# 3
# 3
# 1
# 0
# 0
# 3
# 1
# 3
# 1
# 1
# 1
# 0
# 0
# 2
# 2
# 1
# 0
# 6
# 2
# 4
# 4
# 4
# 4
# 3
# 0
# 4
# 1
# 1
# 1
# 3
# 0
# 6
# 0
# 0
# 0
# 6
# 3
# 0
# 3
# 3
# 3
# 1
# 3
# 3
# 6
# 3
# 3
# 3
# 3
# 1
# 1
# 0
# 0
# 1
# 3
# 0
# 0
# 0
# 0
# 4
# 2
# 4
# 4
# 0
# 1
# 3
# 3
# 3
# 1
# 2
# 4
# 1
# 3
# 0
# 3
# 3
# 4
# 4
# 0
# 0
# 0
# 3
# 1
# 1
# 1
# 1
# 1
# 1
# 1
# 3
# 0
# 4
# 7
# 4
# 1
# 0
# 3
# 1
# 3
# 6
# 3
# 1
# 4
# 1
# 4
# 1
# 3
# 3
# 1
# 7
# 0
# 1
# 3
# 1
# 3
# 0
# 0
# 1
# 4
# 4
# 7
# 1
# 0
# 6
# 6
# 3
# 0
# 0
# 3
# 1
# 6
# 1
# 0
# 1
# 0
# 0
# 0
# 1
# 3
# 0
# 0
# 4
# 4
# 2
# 0
# 3
# 3
# 6
# 2
# 2
# 2
# 2
# 2
# 4
# 2
# 0
# 0
# 3
# 3
# 3
# 1
# 1
# 1
# 1
# 1
# 1
# 1
# 3
# 0
# 6
# 6
# 0
# 3
# 1
# 1
# 3
# 3
# 6
# 0
# 0
# 3
# 0
# 0
# 1
# 3
# 3
# 3
# 6
# 3
# 6
# 1
# 1
# 1
# ...

# %% [markdown]
# ## Two Similar Shoes

# %%
#Nike Shoe Example
shoeData.loc[5]
# Out:
# brand                                      SERVUS BY HONEYWELL
# colors                                                     NaN
# categories          All Men's Shoes,Shoes,Men's Shoes,Clothing
# dateUpdated                               2016-07-09T20:26:48Z
# manufacturer                                               NaN
# prices.amountMin                                         55.99
# Name: 5, dtype: object

# %%
shoeData.loc[8]
# Out:
# brand                                      SERVUS BY HONEYWELL
# colors                                                     NaN
# categories          All Men's Shoes,Shoes,Men's Shoes,Clothing
# dateUpdated                               2016-07-09T20:26:48Z
# manufacturer                                               NaN
# prices.amountMin                                          21.4
# Name: 8, dtype: object

# %% [markdown]
# # Example Data Values

# %% [markdown]
# Example Description: [{"dateSeen":["2016-07-09T20:26:48Z"],"sourceURLs":["http://www.walmart.com/ip/Studs-Shoe-Large-Pr-ZSR101BLMLG/39798470"],"value":"
#
# Important Made in USA Origin Disclaimer: For certain items sold by Walmart on Walmart.com, the displayed country of origin information may not be accurate or consistent with manufacturer information. For updated, accurate country of origin data, it is recommended that you rely on product packaging or manufacturer information. Studs, Shoe, Large, PrShoe Studs, Gender: Men's, Size: 10 to 12, Material: Stretch Rubber, Color: Black"}]

# %% [markdown]
# Example Reviews:
#     [{"dateAdded":"2016-06-15T18:15:42Z","dateSeen":["2015-12-14T00:00:00Z"],"sourceURLs":["http://www.amazon.com/Carrera-CA90S-Aviator-Sunglasses-Light/dp/B00OBQTFKU","http://www.amazon.com/Carrera-CA90S-Aviator-Sunglasses-Matte/dp/B00MXUJ92K","http://www.amazon.com/Carrera-CA90S-Aviator-Sunglasses-Ruthenium/dp/B00MXUJDXU","http://www.amazon.com/Carrera-CA90S-Aviator-Sunglasses-Metallic/dp/B00OBQT88Y","http://www.amazon.com/Carrera-Aviator-Sunglasses-Metallic-Ruthenium/dp/B00OBQTJOM"],"text":"A little loose on my head but overall they look great!","title":"... little loose on my head but overall they look great!","username":"M. Klear"},{"date":"2015-12-05T00:00:00Z","dateAdded":"2016-06-15T18:15:42Z","dateSeen":["2016-02-02T00:00:00Z"],"sourceURLs":["http://www.amazon.com/Carrera-CA90S-Aviator-Sunglasses-Matte/dp/B00MXUJ92K","http://www.amazon.com/Carrera-CA90S-Aviator-Sunglasses-Ruthenium/dp/B00MXUJDXU","http://www.amazon.com/Carrera-CA90S-Aviator-Sunglasses-Light/dp/B00OBQTFKU","http://www.amazon.com/Carrera-Aviator-Sunglasses-Metallic-Ruthenium/dp/B00OBQTJOM"],"text":"Great sunglasses. Have ordered a few Carrera glasses from here. Great quality!","title":"Five Stars","username":"Itai menahem"},{"date":"2015-06-29T00:00:00Z","dateAdded":"2016-06-15T18:15:42Z","dateSeen":["2016-02-06T00:00:00Z"],"sourceURLs":["http://www.amazon.com/Carrera-CA90S-Aviator-Sunglasses-Light/dp/B00OBQTFKU","http://www.amazon.com/Carrera-CA90S-Aviator-Sunglasses-Matte/dp/B00MXUJ92K","http://www.amazon.com/Carrera-Aviator-Sunglasses-Metallic-Ruthenium/dp/B00OBQTJOM","http://www.amazon.com/Carrera-CA90S-Aviator-Sunglasses-Ruthenium/dp/B00MXUJDXU","http://www.amazon.com/Carrera-CA90S-Aviator-Sunglasses-Metallic/dp/B00OBQT88Y"],"text":"I love it. The color is amazing","title":"Five Stars","username":"Abdulrahman"},{"dateAdded":"2016-06-15T18:15:42Z","dateSeen":["2016-05-08T00:00:00Z"],"rating":3.0,"sourceURLs":["http://www.amazon.com/Carrera-CA90S-Aviator-Sunglasses-Metallic/dp/B00OBQT88Y","http://www.amazon.com/Carrera-CA90S-Aviator-Sunglasses-Matte/dp/B00MXUJ92K","http://www.amazon.com/Carrera-CA90S-Aviator-Sunglasses-Ruthenium/dp/B00MXUJDXU","https://www.amazon.com/Carrera-CA90S-Aviator-Sunglasses-Matte/dp/B00MXUJ92K","http://www.amazon.com/Carrera-Aviator-Sunglasses-Metallic-Ruthenium/dp/B00OBQTJOM"],"text":"A little loose on my head but overall they look great!","title":"... little loose on my head but overall they look great!","username":"M. Klear"},{"date":"2015-06-09T00:00:00Z","dateAdded":"2016-06-15T18:15:42Z","dateSeen":["2015-10-28T00:00:00Z"],"sourceURLs":["http://www.amazon.com/Carrera-CA90S-Aviator-Sunglasses-Ruthenium/dp/B00MXUJDXU","http://www.amazon.com/Carrera-CA90S-Aviator-Sunglasses-Matte/dp/B00MXUJ92K","http://www.amazon.com/Carrera-Aviator-Sunglasses-Metallic-Ruthenium/dp/B00OBQTJOM","http://www.amazon.com/Carrera-CA90S-Aviator-Sunglasses-Light/dp/B00OBQTFKU","http://www.amazon.com/Carrera-CA90S-Aviator-Sunglasses-Metallic/dp/B00OBQT88Y"],"text":"My man absolutely love these I got for his birthday.","title":"Five Stars","username":"Shaybuttera"},{"date":"2015-04-14T00:00:00Z","dateAdded":"2016-06-15T18:15:42Z","dateSeen":["2016